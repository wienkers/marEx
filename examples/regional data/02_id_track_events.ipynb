# %% [markdown]
# # Regional European Daily Event Analysis: Marine Heatwave ID & Tracking using `MarEx` Regional Mode

# %% [markdown]
# ### `MarEx` Processing Pipeline for Regional European Datasets:
#
# This example demonstrates **regional tracking** capabilities for high-resolution (0.05°) European marine extremes using `marEx.regional_tracker()`. Regional mode is specifically designed for focused geographical studies where coordinate system auto-detection may fail.
#
# ---
#
# 1. **Morphological Pre-Processing**
#     - Performs binary morphological closing using `dask_image.ndmorph` to fill small spatial holes up to `R_fill` cells in radius
#     - Executes binary opening to remove isolated small features of order `R_fill`
#     - Fills gaps in time to maintain event continuity for interruptions up to `T_fill` time steps
#     - Filters out objects smaller than `area_filter_absolute` cells
#
# 2. **Blob Identification**
#     - Labels spatially connected components using efficient connected-component algorithm in `dask_image.ndmeasure`
#     - Computes blob properties (area, centroid, boundaries)
#
# 3. **Temporal Tracking**
#     - Identifies blob overlaps between consecutive time frames
#     - Connects objects across time, applying the following criteria for splitting, merging, & persistence:
#         - Connected objects must overlap by at least fraction `overlap_threshold` of the smaller area
#         - Merged objects retain their original ID, but partition the child area based on the parent of the _nearest-neighbour_ cell (or centroid distance)
#
# 4. **Graph Reduction & Finalisation**
#     - Constructs the complete temporal graph of object evolution through time
#     - Resolves object connectivity graph using `scipy.sparse.csgraph.connected_components`
#     - Creates globally unique IDs for each tracked extreme event
#     - Maps objects into efficient ID-time space for convenient analysis
#     - Computes comprehensive statistics about the lifecycle of each event
#
# The pipeline leverages **dask** for distributed parallel computation, enabling efficient processing of large datasets. \
# A 40-year regional European daily (OSTIA) analysis at full 0.05° resolution on 32 cores takes
# - Basic (i.e. Scannell et al., which involves no merge/split criteria or tracking):  ~3 minutes
# - Full Split/Merge Thresholding & Merge Tracking:  ~15 minutes

# %%
from getpass import getuser
from pathlib import Path

import dask
import xarray as xr

import marEx
import marEx.helper as hpc
# Out:
# 2026-07-28 21:01:44 - marEx - INFO - [PID:54614] - MarEx logging configured - Level: INFO, Mode: normal

# %%
# Lustre Scratch Directory
scratch_dir = Path("/scratch") / getuser()[0] / getuser()

# %%
# Start Dask Cluster
client = hpc.start_local_cluster(
    n_workers=32, threads_per_worker=1, scratch_dir=scratch_dir / "clients"
)  # Specify temporary scratch directory for dask to use
# Out:
# 2026-07-28 21:01:48 - marEx.helper.cluster - INFO - [PID:54614] - Starting local Dask cluster with 32 workers, 1 threads each
# 2026-07-28 21:01:48 - marEx.helper.dask_config - INFO - [PID:54614] - Configuring Dask for HPC environment
# 2026-07-28 21:01:48 - marEx.helper.dask_config - INFO - [PID:54614] - Dask temporary directory: /scratch/b/b382615/clients/tmpsfyklomo
# 2026-07-28 21:01:48 - marEx.helper.dask_config - INFO - [PID:54614] - Dask configuration completed
# 2026-07-28 21:01:48 - marEx.helper.cluster - INFO - [PID:54614] - System resources: 128 physical cores, 256 logical cores, 251.6GB total memory
# 2026-07-28 21:01:48 - marEx.helper.cluster - INFO - [PID:54614] - Memory per worker: 7.86 GB
# 2026-07-28 21:01:48 - marEx.helper.cluster - INFO - [PID:54614] - Starting Local cluster startup
# 2026-07-28 21:01:50 - marEx.helper.cluster - INFO - [PID:54614] - Completed Local cluster startup in 1.97s
# Hostname: l20427
# Forward Port: l20427:8787
# Dashboard Link: localhost:8787/status
# 2026-07-28 21:01:50 - marEx.helper.cluster - INFO - [PID:54614] - Local cluster started successfully - Dashboard: http://127.0.0.1:8787/status
# 2026-07-28 21:01:50 - marEx.helper.cluster - INFO - [PID:54614] - After cluster startup - Memory Usage - RSS: 572.8MB, Virtual: 30741.9MB, Percent: 0.2%, Available: 244422.7MB

# %%
# Choose optimal chunk size & load data
#   N.B.: This is crucial for dask (not only for performance, but also to make the problem tractable)
#         The operations are eventually global-in-space, and so requires the spatial dimension to be contiguous/unchunked
#         We can adjust the chunk size in time depending on available system memory.

chunk_size = {"time": 25, "lat": -1, "lon": -1}

# %%
# Load Pre-processed Data (cf. `01_preprocess_extremes.ipynb`)

file_name = scratch_dir / "mhws" / "extremes_binary_regional_shifting_hobday.zarr"
ds = xr.open_zarr(str(file_name), chunks=chunk_size)

# %%
# Run Regional ID, Tracking, & Merging using marEx.regional_tracker()

# Key differences from global tracker:
# - Uses marEx.regional_tracker() instead of marEx.tracker()
# - Requires explicit coordinate_units specification
# - Optimised for regional coordinate systems

regional_tracker = marEx.regional_tracker(
    ds.extreme_events,
    ds.mask,
    coordinate_units="degrees",  # Explicit specification required for regional mode
    grid_resolution=0.05,  # Grid resolution in degrees, used to calculate the object areas on the globe
    area_filter_absolute=600,  # Remove objects smaller than 600 cells
    R_fill=16,  # Fill small holes with radius < 16 _cells_
    T_fill=4,  # Allow gaps of 4 days and still continue the event tracking with the same ID
    allow_merging=True,  # Allow extreme events to split/merge. Keeps track of merge events & unique IDs.
    overlap_threshold=0.25,  # Overlap threshold for merging events. If overlap > threshold, events merge, are partitioned, and are independently tracked
    nn_partitioning=True,  # Use new NN method to partition merged children areas. If False, reverts to old method of Di Sun et al. 2023.
    verbose=True,
)

extreme_events_ds, merges_ds = regional_tracker.run(return_merges=True)
extreme_events_ds
# Out:
# 2026-07-28 21:01:52 - marEx - INFO - [PID:54614] - configure_logging:177 - MarEx logging configured - Level: DEBUG, Mode: verbose
# 2026-07-28 21:01:52 - marEx.track.tracker - INFO - [PID:54614] - __init__:419 - Initialising MarEx tracker
# 2026-07-28 21:01:52 - marEx.track.tracker - INFO - [PID:54614] - __init__:420 - Grid type: structured
# 2026-07-28 21:01:52 - marEx.track.tracker - INFO - [PID:54614] - __init__:421 - Parameters: R_fill=16, T_fill=4, area_filter_quartile=None, area_filter_absolute=600
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:425 - Tracking options: allow_merging=True, nn_partitioning=True, overlap_threshold=0.25
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - log_dask_info:550 - Binary input data - Dask object - Shape: (9282, 800, 1300), Chunks: ((25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25..., Size: 9653280000
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - log_dask_info:555 - Dask graph size: 373 tasks
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Tracker initialisation - Memory Usage - RSS: 586.5MB, Virtual: 30760.3MB, Percent: 0.2%, Available: 244493.4MB
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:532 - Dimensions: time=time, x=lon, y=lat
# 2026-07-28 21:01:52 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:533 - Coordinates: time=time, x=lon, y=lat
# 2026-07-28 21:01:53 - marEx.track.tracker - INFO - [PID:54614] - __init__:582 - Calculating cell areas from grid resolution: 0.05 degrees
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - _configure_warnings:668 - Configuring warnings and logging for debug level: 0
# 2026-07-28 21:01:54 - marEx.track.tracker - INFO - [PID:54614] - run:730 - Starting complete tracking pipeline
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Pipeline start - Memory Usage - RSS: 637.9MB, Virtual: 49208.3MB, Percent: 0.2%, Available: 244340.5MB
# 2026-07-28 21:01:54 - marEx.track.tracker - INFO - [PID:54614] - run:739 - Step 1/3: Data preprocessing
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Data preprocessing
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Data preprocessing - Memory Usage - RSS: 637.9MB, Virtual: 49208.3MB, Percent: 0.2%, Available: 244340.5MB
# 2026-07-28 21:01:54 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Data preprocessing
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:826 - Computing area of initial binary data
# 2026-07-28 21:01:54 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:828 - Initial raw area: <xarray.DataArray 'extreme_events' (time: 9282)> Size: 74kB
# dask.array<sum-aggregate, shape=(9282,), dtype=int64, chunksize=(25,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 74kB 1997-01-01T12:00:00 ... 2022-05-31T12...
# 2026-07-28 21:01:54 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:831 - Filling spatial holes with radius R_fill=16
# 2026-07-28 21:01:54 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Spatial hole filling
# 2026-07-28 21:03:49 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After spatial hole filling - Memory Usage - RSS: 651.1MB, Virtual: 49220.3MB, Percent: 0.3%, Available: 229806.1MB
# 2026-07-28 21:03:49 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Spatial hole filling - Duration: 115.071s, Performance: 0.01 ops/sec
# 2026-07-28 21:03:49 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:841 - Filling temporal gaps with T_fill=4
# 2026-07-28 21:03:49 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Temporal gap filling
# 2026-07-28 21:06:28 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After temporal gap filling - Memory Usage - RSS: 688.5MB, Virtual: 49249.3MB, Percent: 0.3%, Available: 229701.8MB
# 2026-07-28 21:06:28 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Temporal gap filling - Duration: 159.541s, Performance: 0.01 ops/sec
# 2026-07-28 21:06:28 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:848 - Filtering small objects
# 2026-07-28 21:06:28 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Small object filtering
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54909] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54900] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54950] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54914] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54857] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54957] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54877] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54922] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54881] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54873] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54861] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54966] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54972] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54962] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54954] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54933] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54906] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54890] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54917] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54885] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54865] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:29 - marEx - INFO - [PID:54853] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:06:53 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:858 - Filtered 43599 -> 34687 objects (threshold: 600)
# 2026-07-28 21:06:53 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After object filtering - Memory Usage - RSS: 694.0MB, Virtual: 49254.3MB, Percent: 0.3%, Available: 228481.4MB
# 2026-07-28 21:06:53 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Small object filtering - Duration: 25.145s, Performance: 0.04 ops/sec
# 2026-07-28 21:06:53 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:871 - Persisting preprocessed data in memory
# 2026-07-28 21:07:25 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Data preprocessing - Memory Usage - RSS: 708.7MB, Virtual: 49267.8MB, Percent: 0.3%, Available: 228135.3MB
# 2026-07-28 21:07:25 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Data preprocessing - Duration: 331.247s, Performance: 0.00 ops/sec
# 2026-07-28 21:07:25 - marEx.track.tracker - INFO - [PID:54614] - run:745 - Step 2/3: Object identification and tracking
# 2026-07-28 21:07:25 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Object identification and tracking
# 2026-07-28 21:07:25 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Object identification and tracking - Memory Usage - RSS: 708.7MB, Virtual: 49267.8MB, Percent: 0.3%, Available: 228135.3MB
# 2026-07-28 21:07:25 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Object identification and tracking
# 2026-07-28 21:08:09 - marEx.track.tracker - INFO - [PID:54614] - track_objects:1458 - Finished object identification
# 2026-07-28 21:08:26 - marEx.track.tracker - INFO - [PID:54614] - track_objects:1471 - Finished calculating object properties
# 2026-07-28 21:08:33 - marEx - INFO - [PID:54941] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:08:42 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:647 - Finished finding overlapping objects
# 2026-07-28 21:08:44 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 0 of 372
# 2026-07-28 21:09:06 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 10 of 372
# 2026-07-28 21:09:37 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 20 of 372
# 2026-07-28 21:09:53 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 30 of 372
# 2026-07-28 21:10:14 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 40 of 372
# 2026-07-28 21:10:28 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 50 of 372
# 2026-07-28 21:10:42 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 60 of 372
# 2026-07-28 21:10:58 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 70 of 372
# 2026-07-28 21:11:17 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 80 of 372
# 2026-07-28 21:11:41 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 90 of 372
# 2026-07-28 21:12:22 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 100 of 372
# 2026-07-28 21:12:41 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 110 of 372
# 2026-07-28 21:12:55 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 120 of 372
# 2026-07-28 21:13:09 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 130 of 372
# 2026-07-28 21:13:23 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 140 of 372
# 2026-07-28 21:13:58 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 150 of 372
# 2026-07-28 21:14:17 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 160 of 372
# 2026-07-28 21:14:31 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 170 of 372
# 2026-07-28 21:14:44 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 180 of 372
# 2026-07-28 21:14:59 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 190 of 372
# 2026-07-28 21:15:10 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 200 of 372
# 2026-07-28 21:15:27 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 210 of 372
# 2026-07-28 21:15:40 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 220 of 372
# 2026-07-28 21:15:52 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 230 of 372
# 2026-07-28 21:16:02 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 240 of 372
# 2026-07-28 21:16:13 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 250 of 372
# 2026-07-28 21:16:26 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 260 of 372
# 2026-07-28 21:16:45 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 270 of 372
# 2026-07-28 21:17:05 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 280 of 372
# 2026-07-28 21:17:20 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 290 of 372
# 2026-07-28 21:17:39 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 300 of 372
# 2026-07-28 21:17:53 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 310 of 372
# 2026-07-28 21:18:10 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 320 of 372
# 2026-07-28 21:18:23 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 330 of 372
# 2026-07-28 21:18:44 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 340 of 372
# 2026-07-28 21:18:50,646 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.00 GiB -- Worker memory limit: 7.36 GiB
# 2026-07-28 21:19:00 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 350 of 372
# 2026-07-28 21:19:16 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 360 of 372
# 2026-07-28 21:19:29 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:958 - Processing splitting and merging in chunk 370 of 372
# 2026-07-28 21:19:36 - marEx - INFO - [PID:54970] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:19:39 - marEx - INFO - [PID:54848] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:20:06 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:979 - Finished final overlapping objects search
# 2026-07-28 21:20:06 - marEx.track.merge_split - INFO - [PID:54614] - split_and_merge_objects:1084 - Validation passed: All 42153 children have unique parents
# 2026-07-28 21:20:06 - marEx.track.tracker - INFO - [PID:54614] - track_objects:1478 - Finished splitting and merging objects
# 2026-07-28 21:20:19 - marEx.track.merge_split - INFO - [PID:54614] - cluster_rename_objects_and_props:111 - Found 46710 valid object IDs (out of max ID 49183)
# 2026-07-28 21:20:19 - marEx.track.merge_split - INFO - [PID:54614] - cluster_rename_objects_and_props:141 - Identified 4557 connected components (events)
# 2026-07-28 21:21:31 - marEx.track.merge_split - INFO - [PID:54614] - cluster_rename_objects_and_props:379 - Recalculating area and centroid properties for potentially disjoint events...
# 2026-07-28 21:21:31 - marEx.track.merge_split - INFO - [PID:54614] - cluster_rename_objects_and_props:543 - Computing area and centroid properties in parallel...
# 2026-07-28 21:21:32 - marEx.track.merge_split - INFO - [PID:54614] - cluster_rename_objects_and_props:580 - Property recalculation complete.
# 2026-07-28 21:21:32 - marEx.track.tracker - INFO - [PID:54614] - track_objects:1501 - Finished clustering and renaming objects into coherent consistent events
# 2026-07-28 21:21:44 - marEx.track.tracker - INFO - [PID:54614] - run_tracking:957 - Finished tracking all extreme events!
# 2026-07-28 21:21:44 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Object identification and tracking - Memory Usage - RSS: 38307.9MB, Virtual: 86864.8MB, Percent: 14.9%, Available: 145899.2MB
# 2026-07-28 21:21:44 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Object identification and tracking - Duration: 858.826s, Performance: 0.00 ops/sec
# 2026-07-28 21:21:44 - marEx.track.tracker - INFO - [PID:54614] - run:756 - Step 3/3: Computing event statistics and attributes
# 2026-07-28 21:21:44 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Computing event statistics and attributes
# 2026-07-28 21:21:44 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Computing event statistics and attributes - Memory Usage - RSS: 38307.9MB, Virtual: 86864.8MB, Percent: 14.9%, Available: 145803.4MB
# 2026-07-28 21:21:44 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Computing event statistics and attributes
# Tracking Statistics:
#    Binary Hobday to Processed Area Fraction: 0.6995516905716256
#    Total Object Area IDed (cells): 330777984.0
#    Number of Initial Pre-Filtered Objects: 43599
#    Number of Final Filtered Objects: 34687
#    Area Cutoff Threshold (cells): 600
#    Accepted Area Fraction: 0.9965096377151872
#    Total Events Tracked: 4557
#    Total Merging Events Recorded: 7414
# 2026-07-28 21:21:50 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Computing event statistics and attributes - Memory Usage - RSS: 38382.6MB, Virtual: 86938.9MB, Percent: 14.9%, Available: 154034.5MB
# 2026-07-28 21:21:50 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Computing event statistics and attributes - Duration: 6.088s, Performance: 0.16 ops/sec
# 2026-07-28 21:21:50 - marEx.track.tracker - INFO - [PID:54614] - run:765 - Tracking pipeline completed successfully - 4557 events identified
# 2026-07-28 21:21:50 - marEx.track.tracker - DEBUG - [PID:54614] - run:766 - Final dataset dimensions: FrozenMappingWarningOnValuesAccess({'time': 9282, 'lat': 800, 'lon': 1300, 'ID': 4557, 'component': 2, 'sibling_ID': 15})
# 2026-07-28 21:21:50 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Pipeline completion - Memory Usage - RSS: 38382.6MB, Virtual: 86938.9MB, Percent: 14.9%, Available: 154034.5MB
# 2026-07-28 21:21:50 - marEx.track.tracker - DEBUG - [PID:54614] - run:770 - Returning both events and merge datasets
# <xarray.Dataset> Size: 42GB
# Dimensions:       (time: 9282, lat: 800, lon: 1300, ID: 4557, component: 2,
#                    sibling_ID: 15)
# Coordinates:
#   * time          (time) datetime64[ns] 74kB 1997-01-01T12:00:00 ... 2022-05-...
#   * ID            (ID) int32 18kB 1 2 3 4 5 6 ... 4552 4553 4554 4555 4556 4557
#   * component     (component) int64 16B 0 1
#   * lat           (lat) float32 3kB 30.02 30.08 30.12 ... 69.88 69.93 69.97
#   * lon           (lon) float32 5kB -19.98 -19.92 -19.88 ... 44.88 44.92 44.97
# Dimensions without coordinates: sibling_ID
# Data variables:
#     ID_field      (time, lat, lon) int32 39GB dask.array<chunksize=(1, 800, 1300), meta=np.ndarray>
#     global_ID     (time, ID) int32 169MB dask.array<chunksize=(1, 4557), meta=np.ndarray>
#     area          (time, ID) float32 169MB dask.array<chunksize=(1, 4557), meta=np.ndarray>
#     centroid      (component, time, ID) float32 338MB dask.array<chunksize=(1, 1, 4557), meta=np.ndarray>
#     presence      (time, ID) bool 42MB dask.array<chunksize=(1, 4557), meta=np.ndarray>
#     time_start    (ID) datetime64[ns] 36kB dask.array<chunksize=(4557,), meta=np.ndarray>
#     time_end      (ID) datetime64[ns] 36kB dask.array<chunksize=(4557,), meta=np.ndarray>
#     merge_ledger  (time, ID, sibling_ID) int32 3GB dask.array<chunksize=(1, 4557, 15), meta=np.ndarray>
# Attributes: (12/14)
#     allow_merging:               1
#     N_objects_prefiltered:       43599
#     N_objects_filtered:          34687
#     N_events_final:              4557
#     R_fill:                      16
#     T_fill:                      4
#     ...                          ...
#     accepted_area_fraction:      0.9965096377151872
#     preprocessed_area_fraction:  0.6995516905716256
#     overlap_threshold:           0.25
#     nn_partitioning:             1
#     total_merges:                7414
#     multi_parent_merges:         3110

# %%
merges_ds
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:        (merge_ID: 7414, parent_idx: 15, child_idx: 15)
# Dimensions without coordinates: merge_ID, parent_idx, child_idx
# Data variables:
#     parent_IDs     (merge_ID, parent_idx) int32 445kB 1 2 -1 -1 ... -1 -1 -1 -1
#     child_IDs      (merge_ID, child_idx) int32 445kB 6 34688 -1 -1 ... -1 -1 -1
#     overlap_areas  (merge_ID, parent_idx) int32 445kB 5298 2601 -1 ... -1 -1 -1
#     merge_time     (merge_ID) datetime64[ns] 59kB 1997-01-02T12:00:00 ... 202...
#     n_parents      (merge_ID) int8 7kB 2 2 2 2 3 3 2 2 2 2 ... 2 2 2 2 2 2 2 2 2
#     n_children     (merge_ID) int8 7kB 2 2 2 2 3 3 2 2 2 2 ... 2 2 2 2 2 2 2 2 2
# Attributes:
#     fill_value:  -1

# %%
# Save IDed/Tracked/Merged Events to `zarr` for more efficient parallel I/O

file_name = scratch_dir / "mhws" / "extreme_events_merged_regional_shifting.zarr"
extreme_events_ds.to_zarr(file_name, mode="w")

# %%
# Save Merges Dataset to netcdf
file_name = scratch_dir / "mhws" / "extreme_events_merged_regional_shifting_merges.nc"
merges_ds.to_netcdf(file_name, mode="w")

# %% [markdown]
# ### Run Basic Tracking for Comparison
# N.B.: This is the current standard method used in the literature, which involves _No_ temporal gap filling, _No_ merging/splitting and _No_ independent event tracking.

# %%
# Run Basic Regional Tracking

basic_regional_tracker = marEx.regional_tracker(
    ds.extreme_events,
    ds.mask,
    coordinate_units="degrees",  # Explicit specification required for regional mode
    area_filter_absolute=600,  # Remove objects smaller than 600 cells
    R_fill=16,  # Fill small holes with radius < 16 _cells_
    T_fill=0,  # No temporal hole filling
    allow_merging=False,  # Do not allow extreme events to split/merge. All touching events adopt the same ID forever (after _and_ before (!)).
)

extreme_events_basic_ds = basic_regional_tracker.run()
extreme_events_basic_ds
# Out:
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - __init__:419 - Initialising MarEx tracker
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - __init__:420 - Grid type: structured
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - __init__:421 - Parameters: R_fill=16, T_fill=0, area_filter_quartile=None, area_filter_absolute=600
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:425 - Tracking options: allow_merging=False, nn_partitioning=False, overlap_threshold=0.5
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_dask_info:550 - Binary input data - Dask object - Shape: (9282, 800, 1300), Chunks: ((25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25..., Size: 9653280000
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_dask_info:555 - Dask graph size: 373 tasks
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Tracker initialisation - Memory Usage - RSS: 39231.7MB, Virtual: 87718.1MB, Percent: 15.2%, Available: 155824.4MB
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:532 - Dimensions: time=time, x=lon, y=lat
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - __init__:533 - Coordinates: time=time, x=lon, y=lat
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - __init__:610 - No cell_areas provided for structured grid - using unit areas (cell counts)
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - _configure_warnings:668 - Configuring warnings and logging for debug level: 0
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - run:730 - Starting complete tracking pipeline
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Pipeline start - Memory Usage - RSS: 39227.7MB, Virtual: 87714.1MB, Percent: 15.2%, Available: 155861.8MB
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - run:739 - Step 1/3: Data preprocessing
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Data preprocessing
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Data preprocessing - Memory Usage - RSS: 39227.7MB, Virtual: 87714.1MB, Percent: 15.2%, Available: 155861.8MB
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Data preprocessing
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:826 - Computing area of initial binary data
# 2026-07-28 21:24:23 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:828 - Initial raw area: <xarray.DataArray 'extreme_events' (time: 9282)> Size: 74kB
# dask.array<sum-aggregate, shape=(9282,), dtype=int64, chunksize=(25,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 74kB 1997-01-01T12:00:00 ... 2022-05-31T12...
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:831 - Filling spatial holes with radius R_fill=16
# 2026-07-28 21:24:23 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Spatial hole filling
# 2026-07-28 21:26:17 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After spatial hole filling - Memory Usage - RSS: 39226.8MB, Virtual: 87713.1MB, Percent: 15.2%, Available: 148187.4MB
# 2026-07-28 21:26:17 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Spatial hole filling - Duration: 113.738s, Performance: 0.01 ops/sec
# 2026-07-28 21:26:17 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:841 - Filling temporal gaps with T_fill=0
# 2026-07-28 21:26:17 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Temporal gap filling
# 2026-07-28 21:26:17 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After temporal gap filling - Memory Usage - RSS: 39226.8MB, Virtual: 87713.1MB, Percent: 15.2%, Available: 148187.4MB
# 2026-07-28 21:26:17 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Temporal gap filling - Duration: 0.035s, Performance: 28.37 ops/sec
# 2026-07-28 21:26:17 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:848 - Filtering small objects
# 2026-07-28 21:26:17 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Small object filtering
# 2026-07-28 21:26:17 - marEx - INFO - [PID:54938] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:17 - marEx - INFO - [PID:54869] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:18 - marEx - INFO - [PID:54893] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:18 - marEx - INFO - [PID:54897] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:18 - marEx - INFO - [PID:54929] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:18 - marEx - INFO - [PID:54946] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:18 - marEx - INFO - [PID:54926] - MarEx logging configured - Level: INFO, Mode: normal
# 2026-07-28 21:26:26 - marEx.track.tracker - INFO - [PID:54614] - run_preprocess:858 - Filtered 44779 -> 34163 objects (threshold: 600)
# 2026-07-28 21:26:26 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After object filtering - Memory Usage - RSS: 39226.8MB, Virtual: 87713.1MB, Percent: 15.2%, Available: 148989.9MB
# 2026-07-28 21:26:26 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Small object filtering - Duration: 9.059s, Performance: 0.11 ops/sec
# 2026-07-28 21:26:26 - marEx.track.tracker - DEBUG - [PID:54614] - run_preprocess:871 - Persisting preprocessed data in memory
# 2026-07-28 21:26:38 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Data preprocessing - Memory Usage - RSS: 39225.0MB, Virtual: 87711.1MB, Percent: 15.2%, Available: 148474.6MB
# 2026-07-28 21:26:38 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Data preprocessing - Duration: 134.277s, Performance: 0.01 ops/sec
# 2026-07-28 21:26:38 - marEx.track.tracker - INFO - [PID:54614] - run:745 - Step 2/3: Object identification and tracking
# 2026-07-28 21:26:38 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Object identification and tracking
# 2026-07-28 21:26:38 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Object identification and tracking - Memory Usage - RSS: 39225.0MB, Virtual: 87711.1MB, Percent: 15.2%, Available: 148474.6MB
# 2026-07-28 21:26:38 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Object identification and tracking
# 2026-07-29 01:23:16 - marEx.track.tracker - INFO - [PID:54614] - run_tracking:957 - Finished tracking all extreme events!
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Object identification and tracking - Memory Usage - RSS: 45394.7MB, Virtual: 94328.1MB, Percent: 17.6%, Available: 131193.3MB
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Object identification and tracking - Duration: 14197.888s, Performance: 0.00 ops/sec
# 2026-07-29 01:23:16 - marEx.track.tracker - INFO - [PID:54614] - run:756 - Step 3/3: Computing event statistics and attributes
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:318 - Initializing Computing event statistics and attributes
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Before Computing event statistics and attributes - Memory Usage - RSS: 45394.7MB, Virtual: 94328.1MB, Percent: 17.6%, Available: 131193.3MB
# 2026-07-29 01:23:16 - marEx.track.tracker - INFO - [PID:54614] - log_timing:323 - Starting Computing event statistics and attributes
# Tracking Statistics:
#    Binary Hobday to Processed Area Fraction: 0.8113125916012991
#    Total Object Area IDed (cells): 285171173.0
#    Number of Initial Pre-Filtered Objects: 44779
#    Number of Final Filtered Objects: 34163
#    Area Cutoff Threshold (cells): 600
#    Accepted Area Fraction: 0.9966532136121626
#    Total Events Tracked: 5505
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - After Computing event statistics and attributes - Memory Usage - RSS: 45396.7MB, Virtual: 94331.1MB, Percent: 17.6%, Available: 131192.5MB
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_timing:335 - Completed Computing event statistics and attributes - Duration: 0.164s, Performance: 6.09 ops/sec
# 2026-07-29 01:23:16 - marEx.track.tracker - INFO - [PID:54614] - run:765 - Tracking pipeline completed successfully - 5505 events identified
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - run:766 - Final dataset dimensions: FrozenMappingWarningOnValuesAccess({'time': 9282, 'lat': 800, 'lon': 1300})
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - log_memory_usage:287 - Pipeline completion - Memory Usage - RSS: 45396.7MB, Virtual: 94331.1MB, Percent: 17.6%, Available: 131192.5MB
# 2026-07-29 01:23:16 - marEx.track.tracker - DEBUG - [PID:54614] - run:773 - Returning events dataset only
# <xarray.Dataset> Size: 39GB
# Dimensions:   (time: 9282, lat: 800, lon: 1300)
# Coordinates:
#   * time      (time) datetime64[ns] 74kB 1997-01-01T12:00:00 ... 2022-05-31T1...
#   * lat       (lat) float32 3kB 30.02 30.08 30.12 30.17 ... 69.88 69.93 69.97
#   * lon       (lon) float32 5kB -19.98 -19.92 -19.88 ... 44.88 44.92 44.97
# Data variables:
#     ID_field  (time, lat, lon) int32 39GB dask.array<chunksize=(1, 800, 1300), meta=np.ndarray>
# Attributes:
#     allow_merging:               0
#     N_objects_prefiltered:       44779
#     N_objects_filtered:          34163
#     N_events_final:              5505
#     R_fill:                      16
#     T_fill:                      0
#     area_filter_quartile:        0.0
#     area_threshold (cells):      600
#     accepted_area_fraction:      0.9966532136121626
#     preprocessed_area_fraction:  0.8113125916012991

# %%
# Save IDed Events to `zarr` for more efficient parallel I/O

file_name = scratch_dir / "mhws" / "extreme_events_basic_regional_shifting.zarr"
extreme_events_basic_ds.to_zarr(file_name, mode="w")
